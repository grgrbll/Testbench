# %%
sys.path.append("./scripts/")
import testbench

testbench.load_env()
testbench.check_env()
# Out:
# [x] tool "aws" found at: /usr/local/bin/aws
# [x] tool "vcpkg" found at: /usr/local/bin/vcpkg
# Tools: 2/2
# # This .env file is generated. Do not edit. See init.sh
# ;TESTBENCH_PROJ_ROOT_DIR=/workspaces/Testbench
# ;CMAKE_TOOLCHAIN_FILE=/workspaces/Testbench/vcpkg/scripts/buildsystems/vcpkg.cmake

# %%
import testbench.aws as aws
from IPython.display import JSON
import uuid
from IPython.display import display_javascript, display_html, display
import json
import yaml
class RenderJSON(object):
    def __init__(self, json_data):
        if isinstance(json_data, dict):
            self.json_str = json.dumps(json_data)
        else:
            self.json_str = json_data
        self.uuid = str(uuid.uuid4())

    def _ipython_display_(self):
        display_html('<div id="{}" style="height: 600px; width:100%;"></div>'.format(self.uuid), raw=True)
        display_javascript("""
        require(["https://rawgit.com/caldwell/renderjson/master/renderjson.js"], function() {
        document.getElementById('%s').appendChild(renderjson(%s))
        });
        """ % (self.uuid, self.json_str), raw=True)

print(yaml.dump(aws.resources(), indent=1))
# Out:
# cloudformation:
#   StackSummaries:
#   - CreationTime: '2022-10-19T14:48:52.202000+00:00'
#     DeletionTime: '2022-10-19T14:48:54.405000+00:00'
#     DriftInformation:
#       StackDriftStatus: NOT_CHECKED
#     StackId: arn:aws:cloudformation:eu-west-2:817312026201:stack/samplestack/fe90ecb0-4fbc-11ed-a083-02d3a9e92a38
#     StackName: samplestack
#     StackStatus: ROLLBACK_COMPLETE
#     TemplateDescription: 'AWS CloudFormation Sample Template EC2InstanceWithSecurityGroupSample:
#       Create an Amazon EC2 instance running the Amazon Linux AMI. The AMI is chosen
#       based on the region in which the stack is run. This example creates an EC2 security
#       group for the instance to give you SSH access. **WARNING** This template creates
#       an Amazon EC2 instance. You will be billed for the AWS resources used if you
#       create a stack from this template.'
#   - CreationTime: '2022-10-19T13:47:32.221000+00:00'
#     DeletionTime: '2022-10-19T14:05:57.976000+00:00'
#     DriftInformation:
#       StackDriftStatus: NOT_CHECKED
#     StackId: arn:aws:cloudformation:eu-west-2:817312026201:stack/AwsCloudFormationSamples/c23321d0-4fb1-11ed-bf77-06a58bec3088
#     StackName: AwsCloudFormationSamples
#     StackStatus: DELETE_COMPLETE
#     TemplateDescription: 'AWS CloudFormation Sample Template EC2InstanceWithSecurityGroupSample:
#       Create an Amazon EC2 instance running the Amazon Linux AMI. The AMI is chosen
#       based on the region in which the stack is run. This example creates an EC2 security
#       group for the instance to give you SSH access. **WARNING** This template creates
#       an Amazon EC2 instance. You will be billed for the AWS resources used if you
#       create a stack from this template.'
# ec2:
#   instances:
#     Reservations:
#     - Groups: []
#       Instances:
#       - AmiLaunchIndex: 0
#         Architecture: x86_64
#         BlockDeviceMappings: []
#         CapacityReservationSpecification:
#           CapacityReservationPreference: open
#         ClientToken: AwsCl-EC2In-13U6STF3YNBKF
#         CpuOptions:
#           CoreCount: 1
#           ThreadsPerCore: 1
#         EbsOptimized: false
#         EnaSupport: true
#         EnclaveOptions:
#           Enabled: false
#         HibernationOptions:
#           Configured: false
#         Hypervisor: xen
#         ImageId: ami-0765d48d7e15beb93
#         InstanceId: i-02fc684c92429fac2
#         InstanceType: t2.small
#         KeyName: AwsCloudFormationSamples
#         LaunchTime: '2022-10-19T13:47:43+00:00'
#         MaintenanceOptions:
#           AutoRecovery: default
#         MetadataOptions:
#           HttpEndpoint: enabled
#           HttpProtocolIpv6: disabled
#           HttpPutResponseHopLimit: 1
#           HttpTokens: optional
#           InstanceMetadataTags: disabled
#           State: pending
#         Monitoring:
#           State: disabled
#         NetworkInterfaces: []
#         Placement:
#           AvailabilityZone: eu-west-2b
#           GroupName: ''
#           Tenancy: default
#         PlatformDetails: Linux/UNIX
#         PrivateDnsName: ''
#         ProductCodes: []
#         PublicDnsName: ''
#         RootDeviceName: /dev/xvda
#         RootDeviceType: ebs
#         SecurityGroups: []
#         State:
#           Code: 48
#           Name: terminated
#         StateReason:
#           Code: Client.UserInitiatedShutdown
#           Message: 'Client.UserInitiatedShutdown: User initiated shutdown'
#         StateTransitionReason: User initiated (2022-10-19 14:06:00 GMT)
#         Tags:
#         - Key: aws:cloudformation:logical-id
#           Value: EC2Instance
#         - Key: aws:cloudformation:stack-id
#           Value: arn:aws:cloudformation:eu-west-2:817312026201:stack/AwsCloudFormationSamples/c23321d0-4fb1-11ed-bf77-06a58bec3088
#         - Key: aws:cloudformation:stack-name
#           Value: AwsCloudFormationSamples
#         UsageOperation: RunInstances
#         UsageOperationUpdateTime: '2022-10-19T13:47:43+00:00'
#         VirtualizationType: hvm
#       OwnerId: '817312026201'
#       RequesterId: '925882491723'
#       ReservationId: r-0483ba2ee8da50a37
#   key-pairs:
#     KeyPairs:
#     - CreateTime: '2022-10-19T13:18:00+00:00'
#       KeyFingerprint: 64:52:12:31:72:82:ba:60:7f:61:0e:ea:79:d5:83:8c:dc:ec:4a:eb
#       KeyName: AwsCloudFormationSamples
#       KeyPairId: key-0fc81b26a894fde4b
#       KeyType: rsa
#       Tags: []
# route53:
#   HostedZones:
#   - CallerReference: RISWorkflow-RD:5a6142d1-566f-4ca4-8750-13d2ca1f8059
#     Config:
#       Comment: HostedZone created by Route53 Registrar
#       PrivateZone: false
#     Id: /hostedzone/Z01388953SBMBAUER27VB
#     Name: gregorybull.com.
#     ResourceRecordSetCount: 5
# Bad pipe message: %s [b'\xffKVu\xef\xf5\xd3\xe9i\x08\xfd\n\xadH{\x08H\xdc \x8a\xce\xea\xdf"\xd2\x00\xdc\xd7B^\xb0#\xa7\x92\xea\x1902\x94Y~w-OG\xe4\xd1\xa8&\xf4F\x00\x08\x13\x02\x13\x03\x13\x01\x00\xff\x01\x00\x00\x8f\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e']
# Bad pipe message: %s [b'\x831.\xbf{1\x12\xe4\x06\xc2\xde_\xe2Y\x04\xb6~9\x00\x00|']
# Bad pipe message: %s [b"\xc00\x00\xa3\x00\x9f\xcc\xa9\xcc\xa8\xcc\xaa\xc0\xaf\xc0\xad\xc0\xa3\xc0\x9f\xc0]\xc0a\xc0W\xc0S\xc0+\xc0/\x00\xa2\x00\x9e\xc0\xae\xc0\xac\xc0\xa2\xc0\x9e\xc0\\\xc0`\xc0V\xc0R\xc0$\xc0(\x00k\x00j\xc0#\xc0'\x00g\x00@\xc0\n\xc0\x14\x009\x008\xc0\t\xc0\x13\x003\x002\x00\x9d\xc0\xa1\xc0\x9d\xc0Q\x00\x9c\xc0\xa0\xc0\x9c\xc0P\x00=\x00<\x005\x00/\x00\x9a\x00\x99\xc0\x07\xc0\x11\x00\x96\x00\x05\x00\xff\x01\x00\x00j\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x000\x00.\x04\x03\x05\x03\x06"]
# Bad pipe message: %s [b'\x07\x08']
# Bad pipe message: %s [b"x\xd3M\x00!\x05\x83_\xb7\x1dn\t\xcd9u\xa8Z\xdb\x00\x00\xa6\xc0,\xc00\x00\xa3\x00\x9f\xcc\xa9\xcc\xa8\xcc\xaa\xc0\xaf\xc0\xad\xc0\xa3\xc0\x9f\xc0]\xc0a\xc0W\xc0S\xc0+\xc0/\x00\xa2\x00\x9e\xc0\xae\xc0\xac\xc0\xa2\xc0\x9e\xc0\\\xc0`\xc0V\xc0R\xc0$\xc0(\x00k\x00j\xc0s\xc0w\x00\xc4\x00\xc3\xc0#\xc0'\x00g\x00@\xc0r\xc0v\x00\xbe\x00\xbd\xc0\n\xc0\x14\x009\x008\x00\x88\x00\x87\xc0\t\xc0\x13\x003\x002\x00\x9a\x00\x99\x00E\x00D\xc0\x07\xc0\x11\xc0\x08\xc0\x12\x00\x16\x00\x13\x00\x9d\xc0\xa1\xc0\x9d\xc0Q\x00\x9c\xc0\xa0\xc0\x9c\xc0P\x00=\x00\xc0\x00<\x00\xba\x005\x00\x84\x00/\x00\x96\x00A\x00\x05\x00\n\x00\xff\x01\x00\x00j\x00\x00\x00\x0e\x00\x0c\x00\x00\t127", b'.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x000\x00']
# Bad pipe message: %s [b'\t\x08\n\x08\x0b\x08\x04']
# Bad pipe message: %s [b'\x03\x05\x03\x06\x03\x08\x07\x08\x08\x08\t\x08\n\x08\x0b\x08\x04\x08\x05\x08\x06\x04\x01\x05\x01\x06\x01\x03\x03\x02\x03\x03\x01\x02\x01\x03\x02\x02\x02\x04\x02\x05\x02\x06\x02']
# Bad pipe message: %s [b'\x08\x06\x04\x01\x05\x01\x06', b'', b'\x03\x03']
# Bad pipe message: %s [b'\x95z\xe8#\xe3T\xaa\xfd\x02tP\xd3R:\xeb\xb5\x8c\xc2\x00\x00>\xc0\x14\xc0\n\x009\x008\x007\x006\xc0\x0f\xc0\x05\x005\xc0\x13\xc0\t\x003\x002\x001\x000\xc0\x0e\xc0\x04\x00/\x00\x9a\x00\x99\x00\x98\x00\x97\x00\x96\x00\x07\xc0\x11\xc0\x07\xc0\x0c\xc0\x02\x00\x05\x00\x04\x00\xff\x02\x01\x00\x00C\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x1c\x00\x1a']
# Bad pipe message: %s [b'']
# Bad pipe message: %s [b'', b'\x02']
# Bad pipe message: %s [b'\x05\x02\x06']
# Bad pipe message: %s [b'J*\x17HM\xbf>\x11\xe6\xdf\xe9\x151\xe9\x07\xe0\xa7-\x00\x00\xa2\xc0\x14\xc0\n\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00:\x00\x89\xc0\x0f\xc0\x05\x005\x00\x84\xc0\x13\xc0\t\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x004\x00\x9b\x00F\xc0\x0e\xc0\x04\x00/\x00\x96\x00A\x00\x07\xc0\x11\xc0\x07\xc0\x16\x00\x18\xc0\x0c\xc0\x02\x00\x05\x00\x04\xc0\x12\xc0\x08\x00\x16\x00\x13\x00\x10\x00\r\xc0\x17\x00\x1b\xc0\r\xc0\x03\x00\n\x00\x15\x00\x12\x00\x0f\x00\x0c\x00\x1a\x00\t\x00\x14\x00\x11\x00\x19\x00\x08\x00\x06\x00\x17\x00\x03\xc0\x10\xc0\x06\xc0\x15\xc0\x0b\xc0\x01\x00\x02\x00\x01\x00\xff\x02\x01\x00\x00C\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x1c\x00\x1a\x00\x17\x00\x19\x00\x1c\x00\x1b\x00\x18\x00\x1a\x00\x16\x00\x0e\x00\r\x00']
# Bad pipe message: %s [b'\x0c\x00\t\x00\n\x00#\x00\x00\x00']
# Bad pipe message: %s [b'\x97\xc9\xe4\xce1\x0b+\xa8\x93w\x0f\xfat~.c\xf1\x12\x00\x00>\xc0\x14\xc0\n\x009\x008\x007\x006\xc0\x0f\xc0\x05\x005\xc0\x13\xc0\t\x003\x002\x001\x000\xc0\x0e\xc0\x04\x00/\x00\x9a\x00\x99\x00\x98\x00\x97\x00\x96\x00\x07\xc0\x11\xc0\x07\xc0\x0c\xc0\x02\x00\x05\x00\x04\x00\xff\x02\x01\x00\x00C\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.', b'\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x1c\x00\x1a\x00\x17\x00\x19\x00\x1c\x00\x1b\x00\x18\x00\x1a\x00\x16\x00\x0e\x00\r\x00\x0b\x00\x0c\x00\t\x00\n\x00#\x00\x00\x00\x0f\x00\x01\x01']
# Bad pipe message: %s [b'^Zjn\xa8\x02H7\xd6\x9c\xdd\x06J.{\x1c\xe7,\x00\x00\xa2\xc0\x14\xc0\n\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00:\x00\x89\xc0\x0f\xc0\x05\x005\x00\x84\xc0\x13\xc0\t\x003\x002\x001\x00']
# Bad pipe message: %s [b'\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x004\x00\x9b\x00F\xc0\x0e\xc0\x04\x00/\x00\x96\x00A\x00\x07\xc0\x11\xc0\x07\xc0\x16\x00\x18\xc0\x0c\xc0\x02']
# Bad pipe message: %s [b'\x1b\x87;V[\x1f\xb9uQ\xf7\xd1##\x04\xbaFF\x0f\x00\x00\x86\xc00\xc0,\xc0(\xc0$', b"\xc0\n\x00\xa5\x00\xa3\x00\xa1\x00\x9f\x00k\x00j\x00i\x00h\x009\x008\x007\x006\xc02\xc0.\xc0*\xc0&\xc0\x0f\xc0\x05\x00\x9d\x00=\x005\xc0/\xc0+\xc0'\xc0#\xc0\x13\xc0\t\x00\xa4\x00\xa2\x00\xa0\x00\x9e\x00g\x00@\x00?\x00>\x003\x002\x001\x000\xc01\xc0-\xc0)\xc0%\xc0\x0e\xc0\x04\x00\x9c\x00<\x00/\x00\x9a\x00\x99\x00\x98\x00\x97\x00\x96\x00\x07\xc0\x11\xc0\x07\xc0\x0c\xc0\x02\x00\x05\x00\x04\x00\xff\x02\x01\x00\x00g\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x1c\x00\x1a\x00\x17\x00\x19\x00\x1c\x00\x1b\x00\x18\x00\x1a\x00\x16\x00\x0e\x00\r\x00\x0b\x00\x0c\x00\t\x00\n\x00#\x00\x00"]

# %%
t.build()

# %%
t.test()
